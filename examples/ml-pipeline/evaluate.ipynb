# %%
# Simulated test data
print("Loading test data...")
X_test = [[1, 2], [3, 4]]
print(f"X_test shape: ({len(X_test)}, {len(X_test[0])})")
# Out:
# Loading test data...
# X_test shape: (2, 2)

# %%
test_acc = 1.0
print(f"Test accuracy: {test_acc}")
# Out:
# Test accuracy: 1.0
